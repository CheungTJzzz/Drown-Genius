# %% [markdown]
# # Test

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 2*np.pi, 1000)
y = np.sin(x)
z = np.cos(x)
plt.plot(x,y)
plt.plot(x,z)
plt.title('sine and cosine')
plt.grid()
plt.show()

# %% [markdown]
# # System Information

# %%
# %%capture
# !conda install -y psutil py-cpuinfo
import psutil
import platform
from cpuinfo import get_cpu_info

# %%
# Get system information
cpu_info = get_cpu_info()
cpu_model = cpu_info['brand_raw']
cpu_cores = psutil.cpu_count(logical=False)
ram_info = f"RAM Total: {psutil.virtual_memory().total / (1024**3):.2f} GB"

# Print system information
print("\nSystem Information:")
print(f"Platform: {platform.platform()}")
print(f"CPU Model: {cpu_model}")
print(f"Number of CPU Cores: {cpu_cores}")
print(ram_info)

# Get Python-related information
python_version = platform.python_version()

# Print Python information
print("\nPython Information:")
print(f"Python Version: {python_version}")
print("NumPy version:", np.__version__)
# Out:
# System Information:
# Platform: Linux-6.1.0-18-amd64-x86_64-with-glibc2.36
# CPU Model: AMD Ryzen 7 PRO 6850HS with Radeon Graphics
# Number of CPU Cores: 8
# RAM Total: 30.66 GB
#
# Python Information:
# Python Version: 3.10.11
# NumPy version: 1.24.3
